# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
# more info on callbakcs: https://keras.io/callbacks/ model saver is cool too.
from tensorflow.keras.callbacks import TensorBoard
import pickle
import time

pickle_in = open("X.picle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.picle","rb")
y = pickle.load(pickle_in)

X = X/255.0

dense_layers = [0, 1, 2]
layer_sizes = [32, 64, 128]
conv_layers = [1, 2, 3]

# %%
import numpy as np
y=np.array(y)
for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            #print(NAME)

            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))

            for l in range(conv_layer-1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))

            model.add(Flatten())

            for _ in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))

            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'],
                          )

            model.fit(X, y,batch_size=32,epochs=10,validation_split=0.3,callbacks=[tensorboard])
# Out:
# Epoch 1/10
# 546/546 [==============================] - 5s 9ms/step - loss: 0.6367 - accuracy: 0.6393 - val_loss: 0.5856 - val_accuracy: 0.7018
# Epoch 2/10
# 546/546 [==============================] - 4s 8ms/step - loss: 0.5710 - accuracy: 0.7113 - val_loss: 0.5560 - val_accuracy: 0.7194
# Epoch 3/10
# 546/546 [==============================] - 4s 8ms/step - loss: 0.5375 - accuracy: 0.7344 - val_loss: 0.5345 - val_accuracy: 0.7358
# Epoch 4/10
# 546/546 [==============================] - 4s 8ms/step - loss: 0.5127 - accuracy: 0.7502 - val_loss: 0.5383 - val_accuracy: 0.7269
# Epoch 5/10
# 546/546 [==============================] - 4s 8ms/step - loss: 0.4965 - accuracy: 0.7603 - val_loss: 0.5387 - val_accuracy: 0.7285
# Epoch 6/10
# 546/546 [==============================] - 4s 8ms/step - loss: 0.4821 - accuracy: 0.7726 - val_loss: 0.5274 - val_accuracy: 0.7416
# Epoch 7/10
# 546/546 [==============================] - 4s 8ms/step - loss: 0.4657 - accuracy: 0.7822 - val_loss: 0.5203 - val_accuracy: 0.7445
# Epoch 8/10
# 546/546 [==============================] - 4s 8ms/step - loss: 0.4565 - accuracy: 0.7824 - val_loss: 0.5191 - val_accuracy: 0.7414
# Epoch 9/10
# 546/546 [==============================] - 4s 8ms/step - loss: 0.4445 - accuracy: 0.7926 - val_loss: 0.5225 - val_accuracy: 0.7394
# Epoch 10/10
# 546/546 [==============================] - 4s 8ms/step - loss: 0.4384 - accuracy: 0.7991 - val_loss: 0.5333 - val_accuracy: 0.7380
# Epoch 1/10
# 546/546 [==============================] - 6s 12ms/step - loss: 0.6371 - accuracy: 0.6288 - val_loss: 0.5743 - val_accuracy: 0.7012
# Epoch 2/10
# 546/546 [==============================] - 6s 11ms/step - loss: 0.5593 - accuracy: 0.7129 - val_loss: 0.5323 - val_accuracy: 0.7309
# Epoch 3/10
# 546/546 [==============================] - 7s 13ms/step - loss: 0.5122 - accuracy: 0.7500 - val_loss: 0.5291 - val_accuracy: 0.7284
# Epoch 4/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4904 - accuracy: 0.7661 - val_loss: 0.4905 - val_accuracy: 0.7640
# Epoch 5/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4686 - accuracy: 0.7785 - val_loss: 0.4869 - val_accuracy: 0.7647
# Epoch 6/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4546 - accuracy: 0.7874 - val_loss: 0.4941 - val_accuracy: 0.7619
# Epoch 7/10
# 546/546 [==============================] - 10s 18ms/step - loss: 0.4438 - accuracy: 0.7955 - val_loss: 0.4681 - val_accuracy: 0.7786
# Epoch 8/10
# 546/546 [==============================] - 10s 19ms/step - loss: 0.4294 - accuracy: 0.8047 - val_loss: 0.4615 - val_accuracy: 0.7835
# Epoch 9/10
# 546/546 [==============================] - 11s 20ms/step - loss: 0.4121 - accuracy: 0.8135 - val_loss: 0.4603 - val_accuracy: 0.7851
# Epoch 10/10
# 546/546 [==============================] - 14s 25ms/step - loss: 0.4034 - accuracy: 0.8168 - val_loss: 0.4824 - val_accuracy: 0.7732
# Epoch 1/10
#   2/546 [..............................] - ETA: 2:09 - loss: 0.6972 - accuracy: 0.4688WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.272758). Check your callbacks.
# 546/546 [==============================] - 14s 26ms/step - loss: 0.6737 - accuracy: 0.5732 - val_loss: 0.6215 - val_accuracy: 0.6613
# Epoch 2/10
# 546/546 [==============================] - 23s 42ms/step - loss: 0.6009 - accuracy: 0.6756 - val_loss: 0.5585 - val_accuracy: 0.7139
# Epoch 3/10
# 546/546 [==============================] - 19s 34ms/step - loss: 0.5537 - accuracy: 0.7211 - val_loss: 0.5314 - val_accuracy: 0.7297oss: 0.5555 - accuracy:  - E
# Epoch 4/10
# 546/546 [==============================] - 19s 35ms/step - loss: 0.5178 - accuracy: 0.7413 - val_loss: 0.4950 - val_accuracy: 0.765120 - ETA: 1s - l - ETA: 0s - loss: 0.5189 -
# Epoch 5/10
# 546/546 [==============================] - 20s 36ms/step - loss: 0.4878 - accuracy: 0.7653 - val_loss: 0.4825 - val_accuracy: 0.7698
# Epoch 6/10
# 546/546 [==============================] - 20s 36ms/step - loss: 0.4667 - accuracy: 0.7794 - val_loss: 0.4724 - val_accuracy: 0.7758
# Epoch 7/10
# 546/546 [==============================] - 18s 33ms/step - loss: 0.4458 - accuracy: 0.7892 - val_loss: 0.4604 - val_accuracy: 0.7830
# Epoch 8/10
# 546/546 [==============================] - 20s 36ms/step - loss: 0.4277 - accuracy: 0.8024 - val_loss: 0.5187 - val_accuracy: 0.7463
# Epoch 9/10
# 546/546 [==============================] - 17s 32ms/step - loss: 0.4120 - accuracy: 0.8111 - val_loss: 0.4500 - val_accuracy: 0.7847
# Epoch 10/10
# 546/546 [==============================] - 19s 35ms/step - loss: 0.3996 - accuracy: 0.8177 - val_loss: 0.4442 - val_accuracy: 0.7920
# Epoch 1/10
#   2/546 [..............................] - ETA: 2:18 - loss: 0.8012 - accuracy: 0.4688WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.306216). Check your callbacks.
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.122657). Check your callbacks.
# 546/546 [==============================] - 25s 45ms/step - loss: 0.6250 - accuracy: 0.6473 - val_loss: 0.5952 - val_accuracy: 0.6760
# Epoch 2/10
# 546/546 [==============================] - 18s 33ms/step - loss: 0.5502 - accuracy: 0.7244 - val_loss: 0.5512 - val_accuracy: 0.7199
# Epoch 3/10
# 546/546 [==============================] - 20s 37ms/step - loss: 0.5146 - accuracy: 0.7511 - val_loss: 0.5352 - val_accuracy: 0.7326
# Epoch 4/10
# 546/546 [==============================] - 21s 38ms/step - loss: 0.4886 - accuracy: 0.7669 - val_loss: 0.5391 - val_accuracy: 0.7312cy: 0. - ETA: 4s - ETA: 2s - loss:
# Epoch 5/10
# 546/546 [==============================] - 16s 30ms/step - loss: 0.4714 - accuracy: 0.7806 - val_loss: 0.5315 - val_accuracy: 0.7352 E
# Epoch 6/10
# 546/546 [==============================] - 19s 34ms/step - loss: 0.4493 - accuracy: 0.7919 - val_loss: 0.5694 - val_accuracy: 0.7129
# Epoch 7/10
# 546/546 [==============================] - 17s 31ms/step - loss: 0.4348 - accuracy: 0.7991 - val_loss: 0.5304 - val_accuracy: 0.7414
# Epoch 8/10
# 546/546 [==============================] - 17s 30ms/step - loss: 0.4197 - accuracy: 0.8109 - val_loss: 0.5632 - val_accuracy: 0.7222
# Epoch 9/10
# 546/546 [==============================] - 20s 37ms/step - loss: 0.4069 - accuracy: 0.8175 - val_loss: 0.5468 - val_accuracy: 0.7377- accuracy: 0. - ETA: 1s - loss: 0.4 - ETA: 0s - los - ETA: 0s - loss: 0.4068 - accuracy: 0.81
# Epoch 10/10
# 546/546 [==============================] - 21s 38ms/step - loss: 0.3942 - accuracy: 0.8234 - val_loss: 0.5369 - val_accuracy: 0.7400
# Epoch 1/10
#   2/546 [..............................] - ETA: 2:53 - loss: 0.6925 - accuracy: 0.5469WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.372504). Check your callbacks.
# WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.133639). Check your callbacks.
# 546/546 [==============================] - 22s 41ms/step - loss: 0.6295 - accuracy: 0.6377 - val_loss: 0.5629 - val_accuracy: 0.7122
# Epoch 2/10
# 546/546 [==============================] - 21s 38ms/step - loss: 0.5339 - accuracy: 0.7363 - val_loss: 0.5286 - val_accuracy: 0.7378
# Epoch 3/10
# 546/546 [==============================] - 21s 39ms/step - loss: 0.4988 - accuracy: 0.7619 - val_loss: 0.5262 - val_accuracy: 0.7431
# Epoch 4/10
# 546/546 [==============================] - 22s 41ms/step - loss: 0.4704 - accuracy: 0.7776 - val_loss: 0.4923 - val_accuracy: 0.7575
# Epoch 5/10
# 546/546 [==============================] - 22s 41ms/step - loss: 0.4453 - accuracy: 0.7929 - val_loss: 0.4626 - val_accuracy: 0.7805459 - accu
# Epoch 6/10
# 546/546 [==============================] - 21s 38ms/step - loss: 0.4211 - accuracy: 0.8085 - val_loss: 0.4611 - val_accuracy: 0.7855
# Epoch 7/10
# 546/546 [==============================] - 21s 38ms/step - loss: 0.3980 - accuracy: 0.8204 - val_loss: 0.4529 - val_accuracy: 0.7910
# Epoch 8/10
# 546/546 [==============================] - 20s 37ms/step - loss: 0.3767 - accuracy: 0.8358 - val_loss: 0.4495 - val_accuracy: 0.7934
# Epoch 9/10
# 546/546 [==============================] - 20s 36ms/step - loss: 0.3623 - accuracy: 0.8393 - val_loss: 0.4367 - val_accuracy: 0.7994
# Epoch 10/10
# 546/546 [==============================] - 24s 44ms/step - loss: 0.3393 - accuracy: 0.8518 - val_loss: 0.4357 - val_accuracy: 0.8010
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-2-411bdb51cda9> in <module>
#      34                           )
#      35
# ---> 36             model.fit(X, y,batch_size=32,epochs=10,validation_split=0.3,callbacks=[tensorboard])
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     795           data_adapter.train_validation_split((x, y, sample_weight),
#     796                                               validation_split=validation_split,
# --> 797                                               shuffle=False))
#     798
#     799     with self.distribute_strategy.scope(), \
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in train_validation_split(arrays, validation_split, shuffle)
#    1336
#    1337   train_arrays = nest.map_structure(
# -> 1338       functools.partial(_split, indices=train_indices), arrays)
#    1339   val_arrays = nest.map_structure(
#    1340       functools.partial(_split, indices=val_indices), arrays)
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     615
#     616   return pack_sequence_as(
# --> 617       structure[0], [func(*x) for x in entries],
#     618       expand_composites=expand_composites)
#     619
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in _split(t, indices)
#    1333       return t
#    1334     t = ops.convert_to_tensor_v2(t)
# -> 1335     return array_ops.gather_v2(t, indices)
#    1336
#    1337   train_arrays = nest.map_structure(
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\ops\array_ops.py in gather_v2(params, indices, validate_indices, axis, batch_dims, name)
#    4539       name=name,
#    4540       axis=axis,
# -> 4541       batch_dims=batch_dims)
#    4542
#    4543
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\ops\array_ops.py in gather(***failed resolving arguments***)
#    4522     return params.sparse_read(indices, name=name)
#    4523   except AttributeError:
# -> 4524     return gen_array_ops.gather_v2(params, indices, axis, name=name)
#    4525
#    4526
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in gather_v2(params, indices, axis, batch_dims, name)
#    3753         pass  # Add nodes to the TensorFlow graph.
#    3754     except _core._NotOkStatusException as e:
# -> 3755       _ops.raise_from_not_ok_status(e, name)
#    3756   # Add nodes to the TensorFlow graph.
#    3757   if batch_dims is None:
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\tensorflow\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6651   message = e.message + (" name: " + name if name is not None else "")
#    6652   # pylint: disable=protected-access
# -> 6653   six.raise_from(core._status_to_exception(e.code, message), None)
#    6654   # pylint: enable=protected-access
#    6655
#
# C:\ProgramData\Anaconda3\envs\tesnsorflow\lib\site-packages\six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[17462,50,50,1] and type double on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:GatherV2]
